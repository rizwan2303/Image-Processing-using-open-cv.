# %%
# Morphological Operations

# 1. Reading the image and converting it to grayscle image.

import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('smarties.png', cv2.IMREAD_GRAYSCALE)

titles = ['image']
images = [img]

for i in range(1):
    plt.subplot(1, 1, i+1), plt.imshow(images[i], 'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])

plt.show()

# %%
# 2. Converting the loaded/read image into binary image using thresholding operation

_, binary = cv2.threshold(img, 220, 255, cv2.THRESH_BINARY_INV)


titles = ['image','binary']
images = [img,mask]

for i in range(2):
    plt.subplot(1, 2, i+1), plt.imshow(images[i], 'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])

plt.show()

# %%
# 3. Defining a structuring element and performing Dilation operation.

struct = np.ones((2,2), np.uint8)

dilation = cv2.dilate(mask, struct)

titles = ['image','binary','dilation']
images = [img,mask,dilation]

for i in range(3):
    plt.subplot(1, 3, i+1), plt.imshow(images[i], 'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])

plt.show()

# %%
# change structuring element and no. of iterations can be changed to see the variations in dilation opeartions
# for example: struct = np.ones((2,2), np.uint8)
#              dilation = cv2.dilate(mask, struct, iterations = 2)

# %%
# 4. Defining a structuring element and performing Erosion operation.


erosion = cv2.erode(mask, struct, iterations=1)
titles = ['image','binary','dilation','erosion']
images = [img,mask,dilation,erosion]

for i in range(4):
    plt.subplot(2, 2, i+1), plt.imshow(images[i], 'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])

plt.show()

# %%
# 5. Performing all Morphological operations : Dilation,Erosion,Opening and Closing.


import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('smarties.png', cv2.IMREAD_GRAYSCALE)
_, binary = cv2.threshold(img, 220, 255, cv2.THRESH_BINARY_INV)

struct = np.ones((5,5), np.uint8)

dilation = cv2.dilate(binary, struct , iterations=2)
erosion = cv2.erode(binary, struct , iterations=1)
opening = cv2.morphologyEx(binary, cv2.MORPH_OPEN, struct)
closing = cv2.morphologyEx(binary, cv2.MORPH_CLOSE, struct)

titles = ['image', 'mask', 'dilation', 'erosion', 'opening', 'closing']
images = [img, mask, dilation, erosion, opening, closing]

for i in range(6):
    plt.subplot(2, 3, i+1), plt.imshow(images[i], 'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])

plt.show()
